# %% [markdown]
# Darknet 구성

# %%
'''
압축파일에서 train.txt 참고사항
#image 경로 파일(파이썬)
import os
import re

# 디렉토리의 절대경로를 입력받아 해당 디렉토리의 이미지 파일의 경로을 출력
def image_path(image_file_absolute_path):
    return [image_file_absolute_path + '/' + file_name for file_name in os.listdir(image_file_absolute_path) if bool(re.search('(.png|.jpg)$', file_name))]

import sys
sys.path.append('C:/Users/stu20/Documents/Logo_Recognition/workspace/Utility')

import imageUtil
import fileUtil

#train image    
result = ''
for e in image_path('D:/yolo191212/img'):
    result += e + '\n'

fileUtil.write('C:/Users/stu20/Desktop/train_1212.txt', result)

#이미지 앞부분 경로수정 exp/train_images/
'''

'''
학습 실행 중에 런타임이 끊어지므로 
방지하기 위해 코랩을 실행중인 브라우저 창에서 F12를 눌러 console창에 
다음을 설정해준다. 

function ClickConnect() {
 // 백엔드를 할당하지 못했습니다.
// GPU이(가) 있는 백엔드를 사용할 수 없습니다. 가속기가 없는 런타임을 사용하시겠습니까? // 취소 버튼을 찾아서 클릭 
var buttons = document.querySelectorAll("colab-dialog.yes-no-dialog paper-button#cancel"); buttons.forEach(function(btn) { btn.click(); }); 
console.log("1분마다 자동 재연결"); 
document.querySelector("colab-toolbar-button#connect").click(); 
} 
setInterval(ClickConnect,1000*60);

function ClickConnect() {
  // Training시에 너무 출력이 많으면 컴퓨터가 다운되어버리기 때문에 다음 함수를 적용한다.
  // Xpath 경로에 주의.. 현재 상태에서 셀을 추가하거나 제거한다면 Xpath가 변경된다.
  // 만약 Xpath 경로가 다르다면, training 셀에서 clear-focused-or-selected-outputs 를 찾아 Xpath를 재설정해야함
  function getElementByXpath(path) {
  return document.evaluate(path, document, null, XPathResult.FIRST_ORDERED_NODE_TYPE, null).singleNodeValue;
  }
  console.log("1분마다 자동 재연결 및 출력 삭제"); 
  getElementByXpath('/html/body/div[7]/div[2]/div[1]/colab-shaded-scroller/div/div[1]/div/div[2]/div[23]/div[2]/div[2]/div[2]/div[2]/div[1]/div/iron-icon[2]').click()
} 
clickInterval = setInterval(ClickConnect,1000*60);

function training_Loop() {
  // 밤샘 컴퓨터 노동을 위한 Loop
  // Logic: Model Training End -> Weight File Save(10초후) -> Model Training Start(20초후)
  function getElementByXpath(path) {
  return document.evaluate(path, document, null, XPathResult.FIRST_ORDERED_NODE_TYPE, null).singleNodeValue;
  }

  function endTraining() {
  getElementByXpath('/html/body/div[7]/div[2]/div[1]/colab-shaded-scroller/div/div[1]/div/div[2]/div[23]/div[2]/div[2]/div[1]/div[1]/div/div/div[2]/paper-icon-button').click() // model training 시작
  console.log("Training 중지!");
  }

  function weightBackup() {
    // 백업 
    // Xpath 경로에 주의.. 현재 상태에서 셀을 추가하거나 제거한다면 Xpath가 변경된다.
    getElementByXpath('/html/body/div[7]/div[2]/div[1]/colab-shaded-scroller/div/div[1]/div/div[2]/div[25]/div[2]/div[2]/div[1]/div[1]/div/div/div[2]/paper-icon-button').click() // weight 저장 cell을 클릭하는 것
    console.log("weight 파일 백업!"); 
  }

  function startTraining() {
    getElementByXpath('/html/body/div[7]/div[2]/div[1]/colab-shaded-scroller/div/div[1]/div/div[2]/div[23]/div[2]/div[2]/div[1]/div[1]/div/div/div[2]/paper-icon-button').click() // model training 종료
    console.log("Training 시작!"); 
  }

  setTimeout(endTraining, 1000)
  setTimeout(weightBackup, 1000*10)
  setTimeout(startTraining, 1000*20)
}
trainingInterval = setInterval(training_Loop,1000*60*60);
'''
# Out:
# '\n학습 실행 중에 런타임이 끊어지므로 \n방지하기 위해 코랩을 실행중인 브라우저 창에서 F12를 눌러 console창에 \n다음을 설정해준다. \n\nfunction ClickConnect() {\n // 백엔드를 할당하지 못했습니다.\n// GPU이(가) 있는 백엔드를 사용할 수 없습니다. 가속기가 없는 런타임을 사용하시겠습니까? // 취소 버튼을 찾아서 클릭 \nvar buttons = document.querySelectorAll("colab-dialog.yes-no-dialog paper-button#cancel"); buttons.forEach(function(btn) { btn.click(); }); \nconsole.log("1분마다 자동 재연결"); \ndocument.querySelector("colab-toolbar-button#connect").click(); \n} \nsetInterval(ClickConnect,1000*60);\n\n출처:https://bryan7.tistory.com/1077\n'

# %% [markdown]
# Google Drive에 연결

# %%
# google drive mount
import os.path
from google.colab import drive

if not os.path.exists('/content/gdrive'):
  drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# CUDNN(CUDA Deep Neural Network library)설치

# %%
# cuda 사용을 위해 cuDNN을 colab 환경에 설치(내 드라이브에 있는 cudnn-10.0-linux-x64-v7.5.0.56.tgz 파일을 압축해제 한다.)
# !tar -xzvf /content/gdrive/My\ Drive/cudnn-10.0-linux-x64-v7.5.0.56.tgz -C /usr/local/
# !chmod a+r /usr/local/cuda/include/cudnn.h # cudnn.h 파일에 대해 사용권한 부여
# Out:
# cuda/include/cudnn.h
# cuda/NVIDIA_SLA_cuDNN_Support.txt
# cuda/lib64/libcudnn.so
# cuda/lib64/libcudnn.so.7
# cuda/lib64/libcudnn.so.7.5.0
# cuda/lib64/libcudnn_static.a

# %% [markdown]
# Darknet 다운로드

# %%
# darknet 다운로드
# !git clone https://github.com/vincentgong7/VG_AlexeyAB_darknet
# Out:
# Cloning into 'VG_AlexeyAB_darknet'...
# remote: Enumerating objects: 65, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 8279 (delta 38), reused 0 (delta 0), pack-reused 8214
# Receiving objects: 100% (8279/8279), 14.59 MiB | 7.79 MiB/s, done.
# Resolving deltas: 100% (5548/5548), done.

# %% [markdown]
# Darknet 컴파일

# %%
# 수정된 Makefile 업로드
# !cp -f /content/gdrive/My\ Drive/Makefile /content/VG_AlexeyAB_darknet/Makefile

# %%
# 다크넷폴더로 이동
# %cd VG_AlexeyAB_darknet

# 컴파일 명령 실행
# !make
# Out:
# /content/VG_AlexeyAB_darknet
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# g++  -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/http_stream.cpp -o obj/http_stream.o
# gcc  -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -Ofast -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘transpose_32x32_bits_my’:
# ./src/gemm.c:313:20: warning: unused variable ‘t’ [-Wunused-variable]
#      unsigned x, y, t;
#                     ^
# ./src/gemm.c: In function ‘transpose_8x8_bits_my’:
# ./src/gemm.c:391:20: warning: unused variable ‘t’ [-Wunused-variable]
#      unsigned x, y, t;
#                     ^
# ./src/gemm.c: In function ‘transpose_bin’:
# ./src/gemm.c:486:25: warning: passing argument 1 of ‘get_bit’ from incompatible pointer type [-Wincompatible-pointer-types]
# ...

# %% [markdown]
# Data Set 준비

# %%
# google drive에 있는 data set을 VM으로 카피
import shutil

file_name = 'yolo191212_re.zip' #yolo191212_re.zip으로 수정해서 수행했음

DOWNLOAD_LOCATION = '/content/VG_AlexeyAB_darknet/data'
DRIVE_DATASET_FILE = '/content/gdrive/My Drive/' + file_name 

shutil.copy(DRIVE_DATASET_FILE, DOWNLOAD_LOCATION)

print('Successfully downloaded the dataset')
# Out:
# Successfully downloaded the dataset

# %%
# 복사한 zip 파일의 압축 해제
# !unzip $DOWNLOAD_LOCATION'/'$file_name -d $DOWNLOAD_LOCATION
# Out:
# Archive:  /content/VG_AlexeyAB_darknet/data/yolo191212_re.zip
#   inflating: /content/VG_AlexeyAB_darknet/data/test_images/Budweisser (1).jpg
#   inflating: /content/VG_AlexeyAB_darknet/data/test_images/Budweisser (10).jpg
#   inflating: /content/VG_AlexeyAB_darknet/data/test_images/Budweisser (2).jpg
#   inflating: /content/VG_AlexeyAB_darknet/data/test_images/Budweisser (3).jpg
#   inflating: /content/VG_AlexeyAB_darknet/data/test_images/Budweisser (4).jpg
#   inflating: /content/VG_AlexeyAB_darknet/data/test_images/Budweisser (5).jpg
#   inflating: /content/VG_AlexeyAB_darknet/data/test_images/Budweisser (6).jpg
#   inflating: /content/VG_AlexeyAB_darknet/data/test_images/Budweisser (7).jpg
#   inflating: /content/VG_AlexeyAB_darknet/data/test_images/Budweisser (8).jpg
#   inflating: /content/VG_AlexeyAB_darknet/data/test_images/Budweisser (9).jpg
#   inflating: /content/VG_AlexeyAB_darknet/data/test_images/HITE (1).jpg
# ...

# %%
# !ls

# %%
# 확인
# !ls /content/VG_AlexeyAB_darknet/data/
# Out:
# 9k.tree      goal.txt		       obj.data		 train_images
# coco9k.map   horses.jpg		       obj.names	 train.txt
# coco.names   imagenet.labels.list      openimages.names  valid.txt
# dog.jpg      imagenet.shortnames.list  person.jpg	 voc.names
# eagle.jpg    labels		       scream.jpg	 yolo191212_re
# giraffe.jpg  __MACOSX		       test_images	 yolo191212_re.zip

# %% [markdown]
# Configuration 파일 수정

# %%
#configuration 파일 수정
'''
참고자료: https://eehoeskrap.tistory.com/370 [Enough is not enough]
'''
#Warning: You set batch=32 lower than 64! It is recommended to set batch=64 subdivision=64
# !sed -i 's/batch=1/batch=64/g' cfg/yolov3.cfg
# !sed -i 's/subdivisions=1/subdivisions=32/g' cfg/yolov3.cfg
#!sed -i 's/width=416/width=608/g' cfg/yolov3.cfg
#!sed -i 's/height=416/width=608/g' cfg/yolov3.cfg
# !sed -i 's/max_batches = 500200/max_batches = 20000/g' cfg/yolov3.cfg
# !sed -i 's/steps=400000,450000/steps=16000,18000/g' cfg/yolov3.cfg
# !sed -i 's/classes=80/classes=10/g' cfg/yolov3.cfg
# !sed -i 's/filters=255/filters=45/g' cfg/yolov3.cfg
# !sed -i 's/learning_rate=0.001/learning_rate=0.0001/g' cfg/yolov3.cfg
# !cat cfg/yolov3.cfg
# Out:
# [net]
# # Testing
# batch=64
# subdivisions=32
# # Training
# # batch=64
# # subdivisions=326
# width=416
# height=416
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
#
# learning_rate=0.0001
# burn_in=1000
# max_batches = 20000
# policy=steps
# steps=16000,18000
# scales=.1,.1
#
# [convolutional]
# batch_normalize=1
# filters=32
# size=3
# stride=1
# pad=1
# activation=leaky
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=32
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=1
# stride=1
# pad=1
# ...

# %% [markdown]
# Weight 파일 준비

# %%
#최초 랜덤 가중치 불러오기
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2019-12-18 11:17:12--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  56.0MB/s    in 2.8s
#
# 2019-12-18 11:17:15 (56.0 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# 백업된 weight 파일 가져오기
# !cp /content/gdrive/My\ Drive/yolov3_last.weights /content/VG_AlexeyAB_darknet/backup/yolov3_last.weights

# %% [markdown]
# Model Training

# %%
 #학습
#연결 끊어질 경우 호스팅된 런타임 재실행 클릭하면 멈췄던 부분부터 다시 재실행됨. 

# 최초 학습 시
# !./darknet detector train data/obj.data cfg/yolov3.cfg darknet53.conv.74 -dont_show 

# 이후 학습 시
# !./darknet detector train data/obj.data cfg/yolov3.cfg backup/yolov3_last.weights -dont_show
# Out:
# yolov3
# layer     filters    size              input                output
#    0 tcmalloc: large alloc 1417674752 bytes == 0x55ff78caa000 @  0x7f5916ce2001 0x55ff768d5100 0x55ff76922c69 0x55ff76926a3d 0x55ff7692905f 0x55ff7693bc7f 0x55ff76941a70 0x55ff768c5cff 0x7f58f3671b97 0x55ff768c6fba
# tcmalloc: large alloc 1417674752 bytes == 0x55ffcd4aa000 @  0x7f5916ce2001 0x55ff768d5117 0x55ff76922c69 0x55ff76926a3d 0x55ff7692905f 0x55ff7693bc7f 0x55ff76941a70 0x55ff768c5cff 0x7f58f3671b97 0x55ff768c6fba
# tcmalloc: large alloc 1417674752 bytes == 0x560021caa000 @  0x7f5916ce2001 0x55ff768d5951 0x55ff76922c69 0x55ff76926a3d 0x55ff7692905f 0x55ff7693bc7f 0x55ff76941a70 0x55ff768c5cff 0x7f58f3671b97 0x55ff768c6fba
# conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 ^C

# %% [markdown]
# Weights 파일 백업하기

# %%
# 학습한 가중치 파일을 google drive 에 카피 
# 가중치 파일의 이름을 바꿔서 사용하면 된다. yolov3_last.weights -> 바꾸고 싶은 이름
# 자동으로 생성되는 weights 파일의 이름은 cfg파일의 이름을 따른다.

from os import path
from google.colab import drive

# !cp -f /content/VG_AlexeyAB_darknet/backup/yolov3_last.weights /content/gdrive/My\ Drive/yolov15516_last.weights
# Out:
# cp: cannot stat '/content/VG_AlexeyAB_darknet/backup/yolov3_last.weights': No such file or directory

# %% [markdown]
# 결과 출력준비

# %%
# !mkdir -p /content/VG_AlexeyAB_darknet/results/out_images
# Out:
# out_images

# %% [markdown]
# Detecting 수행

# %%
# 이미지 하나만 detecting 하는 경우
# ./darknet detector test [.data 파일 경로] [.cfg 파일 경로] [weight 파일 경로] [detecting할 이미지 경로]
# '/content/VG_AlexeyAB_darknet/predictions.jpg' 에 저장됨
# !./darknet detector test data/obj.data cfg/yolov3.cfg backup/yolov3_last.weights data/test_images/'KakaoTalk_20191219_132259564.jpg'
# Out:
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256 1.595 BF
# ...

# %%
# !./darknet detector test data/obj.data cfg/yolov3.cfg backup/yolov3_last.weights -dont_show -ext_output 'data/test_images/Budweisser (1).jpg'  > result.txt
# Out:
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256 1.595 BF
# ...

# %%
# 예측
# !./darknet detector batch [.data파일 경로] [cfg파일 경로] [.weights 파일 경로] -save_labels batch [input 이미지 경로] [output 이미지 경로] > [출력결과 경로]
# -ext_output 옵션은 detecting 좌표출력 옵션
# !./darknet detector batch data/obj.data cfg/yolov3.cfg backup/yolov3_last.weights -save_labels batch data/test_images/ results/ -ext_output > results/results.txt
# Out:
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256 1.595 BF
# ...

# %% [markdown]
# 결과 출력

# %%
#results 폴더를 내 구글드라이브로 복사
# !cp -r /content/VG_AlexeyAB_darknet/results /content/gdrive/My\ Drive/yolo_detecting_result

# %%
#예측한 결과 이미지를 출력
def display_image(file_path = '/content/VG_AlexeyAB_darknet/predictions.png'):
    import cv2
    import matplotlib.pyplot as plt
    import os.path

    if os.path.exists(file_path):
      img = cv2.imread(file_path)
      show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
      plt.imshow(show_img)
    else:
      print('failed to open file')

# %%
display_image('/content/VG_AlexeyAB_darknet/predictions.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2c90fc6fd2a1> in <module>()
# ----> 1 display_image('/content/VG_AlexeyAB_darknet/predictions.png')
#
# NameError: name 'display_image' is not defined

# %%
# !ls /content/VG_AlexeyAB_darknet/results/out_images
# Out:
# 'Hoegaarden (10).png'  'Hoegaarden (4).png'  'Hoegaarden (8).png'
# 'Hoegaarden (1).png'   'Hoegaarden (5).png'  'Hoegaarden (9).png'
# 'Hoegaarden (2).png'   'Hoegaarden (6).png'
# 'Hoegaarden (3).png'   'Hoegaarden (7).png'

# %%
from darknet import performDetect as scan #calling 'performDetect' function from darknet.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-a821a1d576b8> in <module>()
# ----> 1 from darknet import performDetect as scan #calling 'performDetect' function from darknet.py
#
# ModuleNotFoundError: No module named 'darknet'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
